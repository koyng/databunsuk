# %%
import matplotlib.pyplot as plt
plt.title('linesyle')
plt.plot([10, 20, 30, 40], color='r', lable='dashed')
plt.plot([40, 30, 20, 10], color='g', lable='dotted')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-96fedd17c535> in <module>
#       1 import matplotlib.pyplot as plt
#       2 plt.title('linesyle')
# ----> 3 plt.plot([10, 20, 30, 40], color='r', lable='dashed')
#       4 plt.plot([40, 30, 20, 10], color='g', lable='dotted')
#       5 plt.legend()
#
# c:\users\82104\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
